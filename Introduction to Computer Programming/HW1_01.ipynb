# %% [markdown]
# 20230808 컴퓨터학과 오승현

# %%
paid = 18730  # 총 금액

# %%
# 10000원
man = paid // 10000
paid = paid % 10000

# %%
# 5000원
five_thousand = paid // 5000
paid = paid % 5000

# %%
# 1000원
thousand = paid // 1000
paid = paid % 1000

# %%
# 500원
five_hundred = paid // 500
paid = paid % 500

# %%
# 100원
hundred = paid // 100
paid = paid % 100

# %%
# 50원
fifty = paid // 50
paid = paid % 50

# %%
# 10원
ten = paid // 10
paid = paid % 10

# %%
# 결과 출력
print("10000원:", man)
print("5000원:", five_thousand)
print("1000원:", thousand)
print("500원:", five_hundred)
print("100원:", hundred)
print("50원:", fifty)
print("10원:", ten)
# Out:
# 10000원: 1
# 5000원: 1
# 1000원: 3
# 500원: 1
# 100원: 2
# 50원: 0
# 10원: 3
