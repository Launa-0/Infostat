# %%
#prob 1

# %%
x1=4
x2=0.5
x3="2"
x4='he'
x5="she"

# %%
2*x1**2
# Out:
# 32

# %%
type(2*x1**2)
# Out:
# int

# %%
-x1/x2+x1
# Out:
# -4.0

# %%
type(-x1/x2+x1)
# Out:
# float

# %%
x1//(x2+1/2)
# Out:
# 4.0

# %%
type(x1//(x2+1/2) )
# Out:
# float

# %%
2*x3+x4
# Out:
# '22he'

# %%
type(2*x3+x4)
# Out:
# str

# %%
x5[1]+x3
# Out:
# 'h2'

# %%
type(x5[1]+x3 )
# Out:
# str

# %%
x5[1:]+x4
# Out:
# 'hehe'

# %%
type(x5[1:]+x4 )
# Out:
# str

# %%
x4 in x5
# Out:
# True

# %%
type(x4 in x5)
# Out:
# bool
