# %%
weight=70.5
height=1.75

# %%
bmi=weight/height ** 2

# %%
print("키: ", height, "(kg)")
print("몸무게: ", weight, "(m)")
print("---> BMI", bmi)
# Out:
# 키:  1.75 (kg)
# 몸무게:  70.5 (m)
# ---> BMI 23.020408163265305
